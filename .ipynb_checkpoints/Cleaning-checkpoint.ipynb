# %% [markdown]
# ## Importing the data

# %%
import pandas as pd
import re
data_2015=pd.read_excel('data/CANDYDATA-2015.xlsx')
data_2016=pd.read_excel('data/CANDYDATA-2016.xlsx')
#data_2017=pd.read_excel('data/CANDYDATA-2017.xlsx')

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# I do not include the 2017 data because, while available, it is not in raw form. I will consider only 2015 and 2016 data.

# %% [markdown]
# ## Inspecting the Raw Data

# %%
data_2015.head()
# Out:
#                 Timestamp How old are you?  \
# 0 2015-10-23 08:46:20.451               35
# 1 2015-10-23 08:46:51.583               41
# 2 2015-10-23 08:47:34.285               33
# 3 2015-10-23 08:47:58.964               31
# 4 2015-10-23 08:48:11.719               30
#
#   Are you going actually going trick or treating yourself?  [Butterfinger]  \
# 0                                                 No                   JOY
# 1                                                 No                   JOY
# 2                                                 No               DESPAIR
# 3                                                 No                   JOY
# 4                                                 No                   NaN
#
#    [100 Grand Bar]  \
# 0              NaN
# 1              JOY
# 2          DESPAIR
# 3              JOY
# 4              JOY
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                            DESPAIR
# 2                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#    [Any full-sized candy bar]  [Black Jacks]  [Bonkers]  [Bottle Caps]  \
# 0                         JOY            NaN        NaN            NaN
# 1                         JOY        DESPAIR    DESPAIR            JOY
# 2                         JOY        DESPAIR    DESPAIR        DESPAIR
# 3                         JOY        DESPAIR    DESPAIR            JOY
# 4                         JOY            NaN        NaN            NaN
#
#    [Box’o’ Raisins]  [Brach products (not including candy corn)]  \
# 0               NaN                                      DESPAIR
# 1           DESPAIR                                      DESPAIR
# 2               JOY                                      DESPAIR
# 3           DESPAIR                                      DESPAIR
# 4               NaN                                          NaN
#
#    [Bubble Gum]  [Cadbury Creme Eggs]  [Candy Corn]  \
# 0       DESPAIR               DESPAIR           NaN
# 1       DESPAIR               DESPAIR       DESPAIR
# 2       DESPAIR                   JOY           JOY
# 3       DESPAIR               DESPAIR       DESPAIR
# 4           NaN                   NaN           NaN
#
#    [Vials of pure high fructose corn syrup, for main-lining into your vein]  \
# 0                                            DESPAIR
# 1                                            DESPAIR
# 2                                            DESPAIR
# 3                                            DESPAIR
# 4                                                NaN
#
#    [Candy that is clearly just the stuff given out for free at restaurants]  \
# 0                                            DESPAIR
# 1                                            DESPAIR
# 2                                            DESPAIR
# 3                                            DESPAIR
# 4                                                NaN
#
#    [Cash, or other forms of legal tender]  [Chiclets]  [Caramellos]  \
# 0                                     JOY         NaN           NaN
# 1                                     JOY     DESPAIR       DESPAIR
# 2                                     JOY     DESPAIR           JOY
# 3                                     JOY     DESPAIR           JOY
# 4                                     JOY         NaN           JOY
#
#    [Snickers]  [Dark Chocolate Hershey]  [Dental paraphenalia]   [Dots]  \
# 0         JOY                       JOY                DESPAIR      JOY
# 1         JOY                   DESPAIR                DESPAIR      JOY
# 2         JOY                       JOY                DESPAIR  DESPAIR
# 3         JOY                       JOY                DESPAIR  DESPAIR
# 4         NaN                       NaN                    NaN      JOY
#
#    [Fuzzy Peaches]  [Generic Brand Acetaminophen]  [Glow sticks]  \
# 0          DESPAIR                        DESPAIR        DESPAIR
# 1          DESPAIR                            JOY            JOY
# 2          DESPAIR                        DESPAIR        DESPAIR
# 3          DESPAIR                        DESPAIR            JOY
# 4              JOY                            NaN            JOY
#
#    [Broken glow stick]  [Goo Goo Clusters]  [Good N' Plenty]  \
# 0              DESPAIR                 NaN           DESPAIR
# 1              DESPAIR             DESPAIR           DESPAIR
# 2              DESPAIR             DESPAIR           DESPAIR
# 3              DESPAIR                 JOY           DESPAIR
# 4                  NaN                 NaN               NaN
#
#    [Gum from baseball cards]  [Gummy Bears straight up]  \
# 0                    DESPAIR                    DESPAIR
# 1                    DESPAIR                    DESPAIR
# 2                    DESPAIR                        JOY
# 3                    DESPAIR                    DESPAIR
# 4                        NaN                        JOY
#
#    [Creepy Religious comics/Chick Tracts]  [Healthy Fruit]  [Heath Bar]  \
# 0                                 DESPAIR          DESPAIR          NaN
# 1                                 DESPAIR          DESPAIR          JOY
# 2                                 DESPAIR              JOY      DESPAIR
# 3                                 DESPAIR          DESPAIR          JOY
# 4                                 DESPAIR              NaN          NaN
#
#    [Hershey’s Kissables]  [Hershey’s Milk Chocolate]  \
# 0                    NaN                         JOY
# 1                    JOY                         JOY
# 2                    JOY                         JOY
# 3                    JOY                         JOY
# 4                    NaN                         NaN
#
#    [Hugs (actual physical hugs)]  [Jolly Rancher (bad flavor)]  \
# 0                        DESPAIR                           NaN
# 1                        DESPAIR                       DESPAIR
# 2                            JOY                       DESPAIR
# 3                        DESPAIR                       DESPAIR
# 4                            NaN                           NaN
#
#    [Jolly Ranchers (good flavor)]  [Kale smoothie]  [Kinder Happy Hippo]  \
# 0                             NaN              NaN                   NaN
# 1                             JOY          DESPAIR               DESPAIR
# 2                         DESPAIR          DESPAIR               DESPAIR
# 3                             JOY          DESPAIR               DESPAIR
# 4                             NaN              NaN                   NaN
#
#    [Kit Kat]  [Hard Candy]  [Lapel Pins]  [LemonHeads]  [Licorice]  \
# 0        NaN           NaN           NaN           NaN         NaN
# 1        JOY       DESPAIR       DESPAIR       DESPAIR     DESPAIR
# 2        JOY           JOY       DESPAIR       DESPAIR     DESPAIR
# 3        JOY       DESPAIR       DESPAIR           JOY     DESPAIR
# 4        NaN           NaN           NaN           JOY         NaN
#
#    [Licorice (not black)]  [Lindt Truffle]  [Lollipops]  [Mars]  [Mary Janes]  \
# 0                     NaN              NaN          NaN     NaN           NaN
# 1                 DESPAIR              JOY      DESPAIR     JOY       DESPAIR
# 2                     JOY          DESPAIR          JOY     JOY       DESPAIR
# 3                     JOY              JOY      DESPAIR     JOY       DESPAIR
# 4                     NaN              NaN          NaN     NaN           NaN
#
#    [Maynards]  [Milk Duds]  [LaffyTaffy]  [Minibags of chips]  \
# 0         NaN          NaN           NaN                  NaN
# 1     DESPAIR          JOY       DESPAIR                  JOY
# 2     DESPAIR      DESPAIR           JOY              DESPAIR
# 3     DESPAIR          JOY           JOY              DESPAIR
# 4         NaN          NaN           NaN                  NaN
#
#    [JoyJoy (Mit Iodine)]  [Reggie Jackson Bar]  [Pixy Stix]  [Nerds]  \
# 0                    NaN                   NaN          NaN      NaN
# 1                DESPAIR               DESPAIR      DESPAIR      JOY
# 2                DESPAIR               DESPAIR          JOY  DESPAIR
# 3                DESPAIR                   JOY      DESPAIR      JOY
# 4                    NaN                   NaN          NaN      JOY
#
#    [Nestle Crunch]  [Now'n'Laters]  [Pencils]  [Milky Way]  \
# 0              NaN             NaN        NaN          JOY
# 1              JOY         DESPAIR    DESPAIR      DESPAIR
# 2              JOY             JOY    DESPAIR          JOY
# 3              JOY             JOY    DESPAIR          JOY
# 4              JOY             NaN        NaN          NaN
#
#    [Reese’s Peanut Butter Cups]  [Tolberone something or other]  [Runts]  \
# 0                           JOY                             NaN      NaN
# 1                           JOY                             JOY      JOY
# 2                           JOY                             JOY  DESPAIR
# 3                           JOY                             JOY      JOY
# 4                           NaN                             NaN      NaN
#
#    [Junior Mints]  [Senior Mints]  [Mint Kisses]  [Mint Juleps]  \
# 0             JOY             NaN            NaN            NaN
# 1         DESPAIR         DESPAIR        DESPAIR        DESPAIR
# 2             JOY         DESPAIR            JOY        DESPAIR
# 3             JOY         DESPAIR            JOY        DESPAIR
# 4             NaN             NaN            NaN            NaN
#
#    [Mint Leaves]  [Peanut M&M’s]  [Regular M&Ms]  [Mint M&Ms]  [Ribbon candy]  \
# 0            NaN             JOY             JOY          NaN             NaN
# 1        DESPAIR             JOY             JOY      DESPAIR         DESPAIR
# 2        DESPAIR             JOY             JOY          JOY         DESPAIR
# 3        DESPAIR             JOY         DESPAIR          JOY         DESPAIR
# 4            NaN             JOY             NaN          NaN             NaN
#
#    [Rolos]  [Skittles]  [Smarties (American)]  [Smarties (Commonwealth)]  \
# 0      JOY         NaN                    JOY                        NaN
# 1      JOY         JOY                DESPAIR                    DESPAIR
# 2  DESPAIR         JOY                    JOY                    DESPAIR
# 3      JOY         JOY                DESPAIR                    DESPAIR
# 4      NaN         JOY                    NaN                        NaN
#
#    [Chick-o-Sticks (we don’t know what that is)]  [Spotted Dick]  [Starburst]  \
# 0                                            NaN             NaN          NaN
# 1                                        DESPAIR         DESPAIR          JOY
# 2                                        DESPAIR         DESPAIR          JOY
# 3                                        DESPAIR         DESPAIR          JOY
# 4                                            NaN             NaN          JOY
#
#    [Swedish Fish]  [Sweetums]  [Those odd marshmallow circus peanut things]  \
# 0             NaN         NaN                                           NaN
# 1             JOY     DESPAIR                                       DESPAIR
# 2             JOY     DESPAIR                                       DESPAIR
# 3             JOY         JOY                                       DESPAIR
# 4             NaN         NaN                                       DESPAIR
#
#    [Three Musketeers]  [Peterson Brand Sidewalk Chalk]  [Peanut Butter Bars]  \
# 0                 NaN                              NaN                   NaN
# 1             DESPAIR                          DESPAIR                   JOY
# 2                 JOY                          DESPAIR               DESPAIR
# 3                 JOY                          DESPAIR                   JOY
# 4                 NaN                              NaN                   NaN
#
#    [Peanut Butter Jars]  [Trail Mix]   [Twix]  [Vicodin]  [White Bread]  \
# 0                   NaN          NaN      NaN        NaN            NaN
# 1               DESPAIR      DESPAIR      JOY        JOY        DESPAIR
# 2               DESPAIR      DESPAIR  DESPAIR    DESPAIR        DESPAIR
# 3               DESPAIR      DESPAIR      JOY        JOY        DESPAIR
# 4                   NaN          NaN      NaN        NaN            NaN
#
#    [Whole Wheat anything]  [York Peppermint Patties]  \
# 0                     NaN                        NaN
# 1                 DESPAIR                    DESPAIR
# 2                 DESPAIR                        JOY
# 3                 DESPAIR                    DESPAIR
# 4                     NaN                        NaN
#
#   Please leave any remarks or comments regarding your choices.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please list any items not included above that give you JOY.  \
# 0                                                NaN
# 1                                                NaN
# 2                           Butterscotch, Mike & Ike
# 3                                                NaN
# 4                                    sour patch kids
#
#   Please list any items not included above that give you DESPAIR.  \
# 0                                                NaN
# 1                                                NaN
# 2                                          Salmiakki
# 3                                                NaN
# 4                                                NaN
#
#   Guess the number of mints in my hand. Betty or Veronica?  \
# 0                                     2           Veronica
# 1                                    10              Betty
# 2                                     4              Betty
# 3                                     5           Veronica
# 4                                     0                ???
#
#   Check all that apply: "I cried tears of sadness at the end of  ____________"  \
# 0                         The last Republican Debate
# 1                         The last Pixar movie I saw
# 2                         The last Pixar movie I saw
# 3                         The last Pixar movie I saw
# 4  The last Pixar movie I saw, The last Republica...
#
#   "That dress* that went viral early this year - when I first saw it, it was ________"  \
# 0                                     White and gold
# 1                                     Blue and black
# 2                                     Blue and black
# 3                                     White and gold
# 4                                     White and gold
#
#    Fill in the blank: "Taylor Swift is a force for ___________"  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your favourite font?  \
# 0                     fuck you
# 1                        arial
# 2                 Proggy Clean
# 3                      georgia
# 4                      verdana
#
#   If you squint really hard, the words "Intelligent Design" would look like.  \
# 0                                        "Bullsh*t!"
# 1                                        "Bullsh*t!"
# 2                                        "Bullsh*t!"
# 3                                        "Bullsh*t!"
# 4                                        "Bullsh*t!"
#
#   Fill in the blank: "Imitation is a form of ____________"  \
# 0                          Lazily flattering someone
# 1                                           Laziness
# 2                          Lazily flattering someone
# 3                          Lazily flattering someone
# 4                          Lazily flattering someone
#
#   Please estimate the degree(s) of separation you have from the following celebrities [JK Rowling]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [JJ Abrams]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Beyoncé]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Bieber]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Kevin Bacon]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Francis Bacon (1561 - 1626)]  \
# 0                                                  1
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#    [Sea-salt flavored stuff, probably chocolate, since this is the "it" flavor of the year]  \
# 0                                                NaN
# 1                                                JOY
# 2                                                JOY
# 3                                                JOY
# 4                                                NaN
#
#    [Necco Wafers] Which day do you prefer, Friday or Sunday?  \
# 0             NaN                                        NaN
# 1         DESPAIR                                        NaN
# 2         DESPAIR                                        NaN
# 3         DESPAIR                                        NaN
# 4             NaN                                        NaN
#
#    Please estimate the degrees of separation you have from the following folks [Bruce Lee]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Please estimate the degrees of separation you have from the following folks [JK Rowling]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Please estimate the degrees of separation you have from the following folks [Malala Yousafzai]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Please estimate the degrees of separation you have from the following folks [Thom Yorke]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Please estimate the degrees of separation you have from the following folks [JJ Abrams]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Please estimate the degrees of separation you have from the following folks [Hillary Clinton]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Please estimate the degrees of separation you have from the following folks [Donald Trump]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Please estimate the degrees of separation you have from the following folks [Beyoncé Knowles]
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
data_2016.head()
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
#   Which state, province, county do you live in?  [100 Grand Bar]  \
# 0                                       Ontario              JOY
# 1                                            il              MEH
# 2                                      Colorado              JOY
# 3                                            il              JOY
# 4                                  South Dakota              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
# 2                                            DESPAIR
# 3                                                MEH
# 4                                            DESPAIR
#
#    [Any full-sized candy bar]  [Black Jacks]  \
# 0                         JOY            MEH
# 1                         JOY            JOY
# 2                         JOY            MEH
# 3                         JOY            MEH
# 4                         JOY        DESPAIR
#
#                  ...                 \
# 0                ...
# 1                ...
# 2                ...
# 3                ...
# 4                ...
#
#   Please estimate the degree(s) of separation you have from the following celebrities [JK Rowling]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [JJ Abrams]  \
# 0                                                  2
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Beyoncé]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Bieber]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Kevin Bacon]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Please estimate the degree(s) of separation you have from the following celebrities [Francis Bacon (1561 - 1626)]  \
# 0                                        3 or higher
# 1                                        3 or higher
# 2                                        3 or higher
# 3                                        3 or higher
# 4                                        3 or higher
#
#   Which day do you prefer, Friday or Sunday?  \
# 0                                     Friday
# 1                                     Friday
# 2                                     Sunday
# 3                                     Sunday
# 4                                     Friday
#
#   Do you eat apples the correct way, East to West (side to side) or do you eat them like a freak of nature, South to North (bottom to top)?  \
# 0                                     South to North
# 1                                       East to West
# 2                                       East to West
# 3                                     South to North
# 4                                       East to West
#
#   When you see the above image of the 4 different websites, which one would you most likely check out (please be honest).  \
# 0                 Science: Latest News and Headlines
# 1                 Science: Latest News and Headlines
# 2                 Science: Latest News and Headlines
# 3                 Science: Latest News and Headlines
# 4                                               ESPN
#
#    [York Peppermint Patties] Ignore
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
# [5 rows x 123 columns]

# %% [markdown]
# The 2015 and 2016 data contain non-candy related questions (ie, degrees of separtion), which do not interest me. I want to remove these, keeping only candy values and possible group-by values for group comparissons (ie, gender, age, location). Furthermore, there are close to 100 different kinds of candy on this list, which is simply not practical for the sake of visualization. I choose 12 of the most populat candies to focus on: Butterfinger, candy corn, snickers, hershey's milk choco, kit kat, milky way, reese's peanut butter cups, m&m (Regular), Skittles, three musketeers, twix, york peppermint patties.
#
# There are a fair number of missing values, which may or may not skew the data if removed. Furthermore, while it seems candy ratings were done on a multiple choice basis (containing choices "DESPAIR", "MEH", and "JOY"), other options were fill-able. This means that different expressions indicating USA, CA, or various states, will have to be combined. I also note that there are several values for age which should be replaced with NaN (ie, one which lists "Really Old" and another with ~10 digits).
#
# The table is also in an inconvenient form. A table indicating the ratings of different candy (perhaps within different country, age, gender groups) would be more useful.

# %% [markdown]
# ## Filtering Extraneous Columns

# %% [markdown]
# As mentioned above, I will keep only columns with candy ratings (for the twelve candies mentioned) and possible group-by values. The 2016 data has more group-by options, whereas the 2015 survey only asked for age. I also add a year column so that I can combine both years into one dataframe. I don't expect to see much change in candy preferences in one year, so I will use data from both years together.

# %%
df15=(data_2015[["How old are you?"," [Butterfinger]"," [Candy Corn]"," [Snickers]"," [Hershey’s Milk Chocolate]",
                " [Kit Kat]"," [Milky Way]"," [Reese’s Peanut Butter Cups]"," [Regular M&Ms]"," [Skittles]",
                " [Three Musketeers]"," [Twix]"," [York Peppermint Patties]"]]).assign(Year=2015)
df16=(data_2016[["How old are you?","Your gender:","Which country do you live in?",
                "Which state, province, county do you live in?"," [Butterfinger]"," [Candy Corn]"," [Snickers]",
                " [Hershey’s Milk Chocolate]"," [Kit Kat]"," [Milky Way]"," [Reese’s Peanut Butter Cups]",
                " [Regular M&Ms]"," [Skittles]"," [Three Musketeers]"," [Twix]"," [York Peppermint Patties]"]]).assign(Year=2016)

# %%
col_names = {"How old are you?":"Age","Your gender:":"Gender","Which country do you live in?":"Country",
                "Which state, province, county do you live in?":"State/Province"," [Butterfinger]":"Butterfinger",
                 " [Candy Corn]":"Candy Corn"," [Snickers]":"Snickers"," [Hershey’s Milk Chocolate]":"Hershey's",
                 " [Kit Kat]":"Kit Kat"," [Milky Way]":"Milky Way"," [Reese’s Peanut Butter Cups]":"Reese's",
                " [Regular M&Ms]":"M&Ms"," [Skittles]":"Skittles"," [Three Musketeers]":"Three Musketeers",
                 " [Twix]":"Twix"," [York Peppermint Patties]":"Peppermint Patties"}
df = (df16.append(df15, sort=False)
        .rename(columns=col_names)
        .reset_index())

# %% [markdown]
# ## Homogenizing Data

# %% [markdown]
# ### Removing Weird Ages

# %% [markdown]
# I choose to simply remove the rows that have non-int or impossible age values rather than marking them NA. There are very few of these values so the removal will affect very little and, in the long run, they probably would have been ignored later anyway (for visualization sake).

# %%
df = df.loc[df.Age.apply(lambda x: isinstance(x, int))]
df = df.loc[df.Age<100]

# %% [markdown]
# ## Gathering All US/Canada Instances

# %%
countries={"France":"FR","Switzerland":"CH","Japan":"JP","Korea":"KR","South Korea":"KR", "croatia":"HR","Portugal":"PT",
           "Mexico":"MX","Germany":"DE","New Zealand":"NZ","Belgium":"BE","Panama":"PA","hungary":"HU", "Brazil":"BR",
           "Philippines":"PH","Sweden":"SE", "Finland":"FI","China":"CN"}

df = (df.replace(regex=r'(Canada)|(CA)\\L', value="CA")
      .replace(regex=r'(u.?s.?a?.?)|(united states( of america)?)', value="US")
      .replace(regex=r'(uk)|(united kingdom( of great britain)?)|(england)', value="UK")
      .replace(regex=r'(the )? netherlands', value="NL")
      .replace(countries)
     )

# %%
df.Country[~df.Country.str.contains("(US)|(CA)|(UK)|(FR)|(JP)|(CH)|(KR)|(HR)|(PT)|(MX)|(DE)|(NZ)|(HU)|(BR)|(PH)|(SE)|(PA)|(FI)|(CN)", na=False)]
# Out:
# C:\Users\Sarah\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# 89                        Neverland
# 188                    Units States
# 200                               B
# 367                          españa
# 411     there isn't one for old men
# 470        The Yoo Ess of Aaayyyyyy
# 483                   United Kindom
# 579                             NaN
# 700                          Brasil
# 802                             EUA
# 832                          sweden
# 874                    United Sates
# 972                 The Netherlands
# 1066                        germany
# 1081                          kenya
# 1140                  United Stetes
# 1153                            NaN
# 1159                   New Zealand
# 1191                    netherlands
# 1209                            NaN
# 1251                   United State
# 1259                            NaN
# 1260                            NaN
# 1261                            NaN
# 1262                            NaN
# 1263                            NaN
# 1264                            NaN
# 1265                            NaN
# 1266                            NaN
# 1268                            NaN
#                    ...
# 6856                            NaN
# 6857                            NaN
# 6859                            NaN
# 6860                            NaN
# 6861                            NaN
# 6862                            NaN
# 6863                            NaN
# 6864                            NaN
# 6865                            NaN
# 6866                            NaN
# 6867                            NaN
# 6868                            NaN
# 6869                            NaN
# 6870                            NaN
# 6871                            NaN
# 6872                            NaN
# 6873                            NaN
# 6875                            NaN
# 6876                            NaN
# 6877                            NaN
# 6878                            NaN
# 6879                            NaN
# 6880                            NaN
# 6881                            NaN
# 6883                            NaN
# 6884                            NaN
# 6885                            NaN
# 6886                            NaN
# 6887                            NaN
# 6888                            NaN
# Name: Country, Length: 5347, dtype: object
